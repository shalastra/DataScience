# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import math
import graphlab
# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,9]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa

# %% [markdown]
# # task
# * Load house sales data: kc_house_data.csv.zip
# * What is the content, could you read it? do you understand collumns?
# * Explore the data for housing
#   * make scatter plot of selected features
#   * create simple regression model of sqft_living to price
#   * evaluate a simple model
#   * is linear function good enough? try quadratic polynomial

# %% [markdown]
# Read in the data. Just to check and know all the columns we visualize the SFrame.
# To later be able to add a constant part to the fits, we are adding a constant valued column. Also a column with squared aquare feet values is added for the square fit later on in the task.
#
# The specified column number ensures that we see all columns.

# %%
houses = graphlab.SFrame("../lectures/data/kc_house_data.csv")
houses['const'] = np.ones(len(houses['id']))
houses['sqft_living_sq'] = houses['sqft_living']**2
houses['const'] = 1
houses.print_rows(num_rows=100, num_columns=23)
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to niklas.eicker@rwth-aachen.de and will expire on November 02, 2018.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1516096165.log
# Finished parsing file /home/nikl/DataScience/lectures/data/kc_house_data.csv
# Parsing completed. Parsed 100 lines in 0.236068 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,float,int,float,int,int,float,int,int,int,int,int,int,int,int,int,float,float,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/nikl/DataScience/lectures/data/kc_house_data.csv
# Parsing completed. Parsed 21613 lines in 0.231721 secs.
# +------------+-----------------+-----------+----------+-----------+-------------+
# |     id     |       date      |   price   | bedrooms | bathrooms | sqft_living |
# +------------+-----------------+-----------+----------+-----------+-------------+
# | 7129300520 | 20141013T000000 |  221900.0 |    3     |    1.0    |     1180    |
# | 6414100192 | 20141209T000000 |  538000.0 |    3     |    2.25   |     2570    |
# | 5631500400 | 20150225T000000 |  180000.0 |    2     |    1.0    |     770     |
# | 2487200875 | 20141209T000000 |  604000.0 |    4     |    3.0    |     1960    |
# | 1954400510 | 20150218T000000 |  510000.0 |    3     |    2.0    |     1680    |
# | 7237550310 | 20140512T000000 | 1225000.0 |    4     |    4.5    |     5420    |
# | 1321400060 | 20140627T000000 |  257500.0 |    3     |    2.25   |     1715    |
# | 2008000270 | 20150115T000000 |  291850.0 |    3     |    1.5    |     1060    |
# | 2414600126 | 20150415T000000 |  229500.0 |    3     |    1.0    |     1780    |
# | 3793500160 | 20150312T000000 |  323000.0 |    3     |    2.5    |     1890    |
# | 1736800520 | 20150403T000000 |  662500.0 |    3     |    2.5    |     3560    |
# | 9212900260 | 20140527T000000 |  468000.0 |    2     |    1.0    |     1160    |
# | 114101516  | 20140528T000000 |  310000.0 |    3     |    1.0    |     1430    |
# | 6054650070 | 20141007T000000 |  400000.0 |    3     |    1.75   |     1370    |
# | 1175000570 | 20150312T000000 |  530000.0 |    5     |    2.0    |     1810    |
# | 1332700270 | 20140519T000000 |  215000.0 |    2     |    2.25   |     1610    |
# | 3869900162 | 20140904T000000 |  335000.0 |    2     |    1.75   |     1030    |
# | 2791500270 | 20140522T000000 |  243500.0 |    4     |    2.5    |     1980    |
# | 5036300431 | 20150311T000000 | 1099880.0 |    5     |    2.75   |     3520    |
# | 4168000060 | 20150226T000000 |  153000.0 |    3     |    1.0    |     1200    |
# | 6021501535 | 20140725T000000 |  430000.0 |    3     |    1.5    |     1580    |
# | 6021501535 | 20141223T000000 |  700000.0 |    3     |    1.5    |     1580    |
# | 1483300570 | 20140908T000000 |  905000.0 |    4     |    2.5    |     3300    |
# | 3422049190 | 20150330T000000 |  247500.0 |    3     |    1.75   |     1960    |
# | 1099611230 | 20140912T000000 |  199000.0 |    4     |    1.5    |     1160    |
# | 722079104  | 20140711T000000 |  314000.0 |    3     |    1.75   |     1810    |
# | 7338200240 | 20140516T000000 |  437500.0 |    3     |    2.5    |     2320    |
# +------------+-----------------+-----------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# |   5650   |  1.0   |     0      |  0   |     3     |   7   |    1180    |       0       |
# |   7242   |  2.0   |     0      |  0   |     3     |   7   |    2170    |      400      |
# |  10000   |  1.0   |     0      |  0   |     3     |   6   |    770     |       0       |
# |   5000   |  1.0   |     0      |  0   |     5     |   7   |    1050    |      910      |
# |   8080   |  1.0   |     0      |  0   |     3     |   8   |    1680    |       0       |
# |  101930  |  1.0   |     0      |  0   |     3     |   11  |    3890    |      1530     |
# |   6819   |  2.0   |     0      |  0   |     3     |   7   |    1715    |       0       |
# |   9711   |  1.0   |     0      |  0   |     3     |   7   |    1060    |       0       |
# |   7470   |  1.0   |     0      |  0   |     3     |   7   |    1050    |      730      |
# |   6560   |  2.0   |     0      |  0   |     3     |   7   |    1890    |       0       |
# |   9796   |  1.0   |     0      |  0   |     3     |   8   |    1860    |      1700     |
# |   6000   |  1.0   |     0      |  0   |     4     |   7   |    860     |      300      |
# |  19901   |  1.5   |     0      |  0   |     4     |   7   |    1430    |       0       |
# |   9680   |  1.0   |     0      |  0   |     4     |   7   |    1370    |       0       |
# |   4850   |  1.5   |     0      |  0   |     3     |   7   |    1810    |       0       |
# |   5000   |  2.0   |     0      |  3   |     3     |   9   |    1980    |      970      |
# |  14040   |  2.0   |     0      |  0   |     3     |   7   |    1890    |       0       |
# |   4300   |  1.5   |     0      |  0   |     4     |   7   |    1600    |       0       |
# |   9850   |  1.0   |     0      |  0   |     4     |   7   |    1200    |       0       |
# |   9774   |  1.0   |     0      |  0   |     4     |   7   |    1250    |       0       |
# |   4980   |  1.0   |     0      |  0   |     4     |   7   |    860     |      760      |
# |  44867   |  1.0   |     0      |  4   |     3     |   9   |    2330    |      720      |
# |   6300   |  2.0   |     0      |  0   |     3     |   8   |    2270    |       0       |
# |   9643   |  1.0   |     0      |  0   |     3     |   7   |    1070    |       0       |
# |   6500   |  2.0   |     0      |  0   |     4     |   8   |    2450    |       0       |
# |   4697   |  1.5   |     0      |  0   |     5     |   6   |    1710    |       0       |
# |   2691   |  2.0   |     0      |  0   |     3     |   8   |    1750    |      700      |
# |   1581   |  1.5   |     0      |  0   |     5     |   8   |    1400    |       0       |
# |   6380   |  1.0   |     0      |  0   |     3     |   7   |    790     |      730      |
# |   7173   |  2.0   |     0      |  0   |     3     |   8   |    2570    |       0       |
# |   3980   |  2.0   |     0      |  0   |     3     |   8   |    2320    |       0       |
# |   1265   |  3.0   |     0      |  0   |     3     |   7   |    1190    |       0       |
# |   5000   |  1.5   |     0      |  0   |     4     |   7   |    1510    |      820      |
# |   3000   |  1.5   |     0      |  0   |     4     |   8   |    1090    |       0       |
# |   6659   |  1.0   |     0      |  0   |     3     |   7   |    1280    |      780      |
# |   3060   |  1.5   |     0      |  0   |     3     |   8   |    1510    |      790      |
# |  34848   |  1.0   |     0      |  0   |     1     |   5   |    930     |      730      |
# |   6000   |  2.0   |     0      |  0   |     4     |   8   |    2360    |       0       |
# |   8075   |  1.0   |     0      |  0   |     2     |   7   |    890     |      330      |
# |   7553   |  2.0   |     0      |  0   |     3     |   8   |    2620    |       0       |
# |   5520   |  2.0   |     0      |  0   |     3     |   9   |    2570    |       0       |
# |  24186   |  1.0   |     0      |  0   |     3     |   8   |    2600    |      1620     |
# |   5639   |  2.0   |     0      |  0   |     3     |   9   |    3595    |       0       |
# |   2280   |  2.0   |     0      |  0   |     3     |   7   |    1570    |       0       |
# |   9656   |  1.0   |     0      |  0   |     4     |   6   |    920     |      360      |
# |  13603   |  2.0   |     0      |  0   |     3     |   8   |    3160    |       0       |
# |   8528   |  1.0   |     0      |  0   |     3     |   6   |    990     |       0       |
# |  13416   |  2.0   |     0      |  0   |     4     |   9   |    2290    |       0       |
# |   5963   |  1.0   |     0      |  0   |     4     |   7   |    1250    |       0       |
# |  65005   |  1.0   |     1      |  2   |     5     |   9   |    2165    |      588      |
# |   9199   |  1.0   |     0      |  0   |     3     |   7   |    1190    |       0       |
# |   9134   |  1.0   |     0      |  0   |     4     |   8   |    1640    |      1510     |
# |   4080   |  1.0   |     0      |  0   |     4     |   7   |    1000    |      410      |
# |   8550   |  1.0   |     0      |  0   |     3     |   7   |    990     |      990      |
# |   6000   |  1.5   |     0      |  0   |     3     |   8   |    2130    |      600      |
# |   5000   |  2.0   |     0      |  0   |     3     |   9   |    2830    |       0       |
# |   4495   |  2.0   |     0      |  0   |     3     |   7   |    2250    |       0       |
# |   4750   |  2.0   |     0      |  0   |     3     |   8   |    2420    |       0       |
# |  14342   |  2.0   |     0      |  4   |     4     |   8   |    3250    |       0       |
# |   9976   |  2.0   |     0      |  0   |     3     |   8   |    1850    |       0       |
# |  21235   |  1.0   |     0      |  3   |     4     |   8   |    1590    |      560      |
# |   8400   |  1.0   |     0      |  0   |     3     |   7   |    1260    |       0       |
# |   8690   |  2.0   |     0      |  0   |     5     |   8   |    2519    |       0       |
# |   1961   |      0       |  98092  | 47.2909 | -122.189 |      1590     |
# |   2006   |      0       |  98056  | 47.5228 | -122.199 |      1900     |
# |   1979   |      0       |  98056  |  47.518 | -122.194 |      1950     |
# |   2006   |      0       |  98136  | 47.5394 | -122.387 |      1030     |
# |   1988   |      0       |  98023  | 47.2897 | -122.372 |      1980     |
# |   2001   |      0       |  98199  | 47.6506 | -122.391 |      2520     |
# |   1962   |      0       |  98023  |  47.322 | -122.351 |      1350     |
# |   1939   |      0       |  98117  |  47.687 | -122.386 |      1570     |
# |   1939   |      0       |  98117  |  47.687 | -122.386 |      1570     |
# |   1946   |     1991     |  98040  | 47.5873 | -122.249 |      1950     |
# |   1967   |      0       |  98032  | 47.3576 | -122.277 |      1750     |
# |   1975   |      0       |  98023  | 47.3036 | -122.378 |      1160     |
# |   1980   |      0       |  98038  | 47.4109 | -121.958 |      1650     |
# |   1992   |      0       |  98045  | 47.4838 | -121.714 |      2550     |
# +----------+--------------+---------+---------+----------+---------------+
# +------------+-------+----------------+
# | sqft_lot15 | const | sqft_living_sq |
# +------------+-------+----------------+
# |    5650    |   1   |   1392400.0    |
# |    7639    |   1   |   6604900.0    |
# |    8062    |   1   |    592900.0    |
# |    5000    |   1   |   3841600.0    |
# |    7503    |   1   |   2822400.0    |
# |   101930   |   1   |   29376400.0   |
# |    6819    |   1   |   2941225.0    |
# |    9711    |   1   |   1123600.0    |
# |    8113    |   1   |   3168400.0    |
# |    7570    |   1   |   3572100.0    |
# |    8925    |   1   |   12673600.0   |
# |    6000    |   1   |   1345600.0    |
# |   12697    |   1   |   2044900.0    |
# |   10208    |   1   |   1876900.0    |
# |    4850    |   1   |   3276100.0    |
# |    4000    |   1   |   8702500.0    |
# |   14018    |   1   |   3572100.0    |
# |    4300    |   1   |   2560000.0    |
# |    5095    |   1   |   1440000.0    |
# |    8850    |   1   |   1562500.0    |
# |    4980    |   1   |   2624400.0    |
# |   20336    |   1   |   9302500.0    |
# |    7005    |   1   |   5152900.0    |
# |    8386    |   1   |   1144900.0    |
# |    6865    |   1   |   6002500.0    |
# |    4705    |   1   |   2924100.0    |
# |    3573    |   1   |   6002500.0    |
# |    3861    |   1   |   1960000.0    |
# |    6235    |   1   |   2310400.0    |
# |    6026    |   1   |   6604900.0    |
# |    3980    |   1   |   5382400.0    |
# |    1756    |   1   |   1416100.0    |
# |    5000    |   1   |   5428900.0    |
# |    5080    |   1   |   1188100.0    |
# |    8720    |   1   |   4243600.0    |
# |    3264    |   1   |   5290000.0    |
# |   11467    |   1   |   2755600.0    |
# |    4700    |   1   |   5569600.0    |
# |    7800    |   1   |   1488400.0    |
# |   11884    |   1   |   6864400.0    |
# |    5669    |   1   |   6604900.0    |
# |   30617    |   1   |   17808400.0   |
# |    5639    |   1   |   12924025.0   |
# |    2640    |   1   |   2464900.0    |
# |    8808    |   1   |   1638400.0    |
# |    9232    |   1   |   9985600.0    |
# |    8840    |   1   |    980100.0    |
# |   13685    |   1   |   5244100.0    |
# |    5100    |   1   |   1562500.0    |
# |   72513    |   1   |   7579009.0    |
# |    9364    |   1   |   1416100.0    |
# |    9133    |   1   |   9922500.0    |
# |    4080    |   1   |   1988100.0    |
# |    6738    |   1   |   3920400.0    |
# |    6000    |   1   |   7452900.0    |
# |    5000    |   1   |   8008900.0    |
# |    4500    |   1   |   5062500.0    |
# |    4750    |   1   |   5856400.0    |
# |   11044    |   1   |   10562500.0   |
# |    8542    |   1   |   3422500.0    |
# |   18900    |   1   |   4622500.0    |
# |    8750    |   1   |   1587600.0    |
# |    9500    |   1   |   6345361.0    |
# |    3090    |   1   |   2371600.0    |
# |    4080    |   1   |   2755600.0    |
# |    4000    |   1   |   7672900.0    |
# |   11049    |   1   |   7398400.0    |
# |    4557    |   1   |   5017600.0    |
# |   12635    |   1   |   1000000.0    |
# |   20158    |   1   |   10240000.0   |
# |   38917    |   1   |   22752900.0   |
# |    4745    |   1   |   1587600.0    |
# |    7807    |   1   |   7562500.0    |
# |    5000    |   1   |   5664400.0    |
# |   50529    |   1   |   3204100.0    |
# |   35020    |   1   |   11764900.0   |
# |    7500    |   1   |   3097600.0    |
# |    5060    |   1   |   1081600.0    |
# |    5693    |   1   |   1988100.0    |
# |   39750    |   1   |   11902500.0   |
# |    5363    |   1   |   5522500.0    |
# |    6405    |   1   |   3610000.0    |
# |    6720    |   1   |   4080400.0    |
# |    8797    |   1   |   2822400.0    |
# |    7203    |   1   |    921600.0    |
# |    4800    |   1   |   4579600.0    |
# |    8165    |   1   |   7075600.0    |
# |    7349    |   1   |   7672900.0    |
# |    2025    |   1   |   2592100.0    |
# |    1106    |   1   |   1060900.0    |
# |    7510    |   1   |   3920400.0    |
# |    6250    |   1   |   12390400.0   |
# |   10500    |   1   |   1440000.0    |
# |    4500    |   1   |   2496400.0    |
# |    4500    |   1   |   2496400.0    |
# |    6045    |   1   |   10890000.0   |
# |   15616    |   1   |   3841600.0    |
# |    6400    |   1   |   1345600.0    |
# |   135036   |   1   |   3276100.0    |
# |   35065    |   1   |   5382400.0    |
# +------------+-------+----------------+
# [21613 rows x 23 columns]

# %% [markdown]
# Create a scatter plot of house price and sqft_living. This is just to visualise the data we will do the simple models on. Later on more features are added and visualisation gets more complicated.

# %%
graphlab.canvas.set_target('ipynb')
houses.show(view="Scatter Plot",x="sqft_living",y="price")

# %% [markdown]
# We will do the linear and quadratic fit on one feature (sqft_living) with graphlab.
#
# 'price' will be our y and we build a function for it from 'const' and 'sqft_living'.

# %%
sqft_model_lin = graphlab.linear_regression.create(houses, validation_set=None, target='price',features=['const', 'sqft_living'])
# Out:
# WARNING: Detected extremely low variance for feature(s) 'const' because all entries are nearly the same.
# Proceeding with model training using all features. If the model does not provide results of adequate quality, exclude the above mentioned feature(s) from the input dataset.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 21613
# Number of features          : 2
# Number of unpacked features : 2
# Number of coefficients    : 3
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 1.070832     | 4362074.683616     | 261440.790302 |
# +-----------+----------+--------------+--------------------+---------------+

# %% [markdown]
# Now a model that takes the squared value of 'sqft_living' into account.
#
# Like a*x² + b*x + c

# %%
sqft_model_quad = graphlab.linear_regression.create(houses, validation_set=None, target='price', features=['const', 'sqft_living', 'sqft_living_sq'])
# Out:
# SUCCESS: Optimal solution found.
# <pre></pre>
# WARNING: Detected extremely low variance for feature(s) 'const' because all entries are nearly the same.
# Proceeding with model training using all features. If the model does not provide results of adequate quality, exclude the above mentioned feature(s) from the input dataset.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 21613
# Number of features          : 3
# Number of unpacked features : 3
# Number of coefficients    : 4
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 0.094889     | 5913021.143248     | 250948.367620 |
# +-----------+----------+--------------+--------------------+---------------+
# SUCCESS: Optimal solution found.

# %% [markdown]
# Compare RMS and max_error of our models via #evaluate(data)

# %%
# RMS of the lin fit
print sqft_model_lin.evaluate(houses)
# Out:
# <pre></pre>
# {'max_error': 4362074.6836155895, 'rmse': 261440.79030169296}

# %%
# RMS of the quadratic fit
print sqft_model_quad.evaluate(houses)
# Out:
# {'max_error': 5913021.143247636, 'rmse': 250948.36761971586}

# %% [markdown]
# RMS of the quadratic method is a little bit better then the linear one, but still very big compared to the values.

# %% [markdown]
# # task
# * Split your data into training sample and test sample
#   * what is trainign error and testing error of your model?
#   * predict the house price for a given sqft_living
#   * predict the sqft_living for a given price of the house

# %%
training , testing  = houses.random_split(.8,seed=0)

# %% [markdown]
# recalculte our linear model on the test data. This time we reserve some data for testing later on.

# %%
sqft_model_lin = graphlab.linear_regression.create(training, validation_set=None, target='price',features=['sqft_living'])
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 0.053913     | 4349521.915863     | 262943.613519 |
# +-----------+----------+--------------+--------------------+---------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %% [markdown]
# Now compare the rms on training data with the rms on test data

# %%
print "training: " + str(sqft_model_lin.evaluate(training)['rmse'])
print "testing: " + str(sqft_model_lin.evaluate(testing)['rmse'])
# Out:
# training: 262943.613519
# testing: 255191.027487

# %% [markdown]
# The errors are comparable...

# %% [markdown]
# ## Methods to predict prices and sqft_living with the fit parameters.

# %% [markdown]
# Methods to predict the price/sqft_living values from the other one.

# %%
def get_house_price(sqft_living):
    return (sqft_model_lin.get('coefficients')['value'][0] + sqft_model_lin.get('coefficients')['value'][1] * sqft_living)

# %% [markdown]
# #roots helps solving for the sqft_living values.

# %%
def get_house_sqft(price):
    coeff = [sqft_model_lin.get('coefficients')['value'][1], (sqft_model_lin.get('coefficients')['value'][0] - price)]
    return np.roots(coeff)[0]

# %% [markdown]
# Predict some sqft_living values for some given prices.

# %%
print "predict house sqft_living for prices:"
print "    500.000 :   " + str(get_house_sqft(500000))
print "    1.000.000 : " + str(get_house_sqft(1000000))
print "    1.500.000 : " + str(get_house_sqft(1500000))
print "    2.500.000 : " + str(get_house_sqft(2500000))
# Out:
# predict house sqft_living for prices:
#     500.000 :   1940.41067055
#     1.000.000 : 3713.72536216
#     1.500.000 : 5487.04005378
#     2.500.000 : 9033.66943701

# %% [markdown]
# Predict some prices for some given sqft_living values.

# %%
print "predict house prices for given sqft:"
print "    1000 : "+ str(get_house_price(1000))
print "    2000 : "+ str(get_house_price(2000))
print "    3000 : "+ str(get_house_price(3000))
print "    4000 : "+ str(get_house_price(4000))
# Out:
# predict house prices for given sqft:
#     1000 : 234843.82806
#     2000 : 516801.679289
#     3000 : 798759.530518
#     4000 : 1080717.38175

# %% [markdown]
# Predictions are comparable with data, but less for very high values (which makes sense).

# %% [markdown]
# # task
# * add more feaures
# * is the model better now?
# * maybe using range of data would work better?

# %%
sqft_model = graphlab.linear_regression.create(training, target='price',features=['sqft_living', 'sqft_lot', 'grade', 'yr_built'])
sqft_model.evaluate(training)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16457
# Number of features          : 4
# Number of unpacked features : 4
# Number of coefficients    : 5
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 0.104601     | 4470923.394273     | 1376556.716989       | 232939.950811 | 218466.517352   |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# SUCCESS: Optimal solution found.
# <pre></pre>
# {'max_error': 4470923.394272704, 'rmse': 232190.92946665827}

# %% [markdown]
# Yes, more features lowered our error, but it is still quite high.
#
# Now we will introduce a range of data and ignore any points that fall out of this range. This will surpress 'outbreakers' and should improve our model accuracy.

# %%
range_houses = houses[(houses['sqft_living'] <= 5000) & (houses['price'] <= 2000000)]
range_training , range_testing  = range_houses.random_split(.8,seed=0)
sqft_model_selected = graphlab.linear_regression.create(range_training, target='price',features=['sqft_living', 'sqft_lot', 'grade', 'yr_built'])
sqft_model_selected.evaluate(range_testing)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16248
# Number of features          : 4
# Number of unpacked features : 4
# Number of coefficients    : 5
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 0.098433     | 1330361.402626     | 852800.823646        | 179669.736189 | 174744.691129   |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# SUCCESS: Optimal solution found.
# <pre></pre>
# {'max_error': 1045808.5150457909, 'rmse': 177178.5720642963}

# %% [markdown]
# on our limited range for prices < 2mil and sqft_living < 5000 the model works much better! On the other hand the points are now also closer together anyways.

# %% [markdown]
# # task
# * predict house price for a house id = 5309101299 (does not exists! using 2008000270 instead)
# * what is this house like?
# * predict house price for a house id = 1925069082

# %%
houses[houses['id'] == 1925069082]
# Out:
# Columns:
# 	id	int
# 	date	str
# 	price	float
# 	bedrooms	int
# 	bathrooms	float
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	int
# 	lat	float
# 	long	float
# 	sqft_living15	int
# 	sqft_lot15	int
# 	const	int
# 	sqft_living_sq	float
#
# Rows: Unknown
#
# Data:
# +------------+-----------------+-----------+----------+-----------+-------------+
# |     id     |       date      |   price   | bedrooms | bathrooms | sqft_living |
# +------------+-----------------+-----------+----------+-----------+-------------+
# | 1925069082 | 20150511T000000 | 2200000.0 |    5     |    4.25   |     4640    |
# +------------+-----------------+-----------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# |  22703   |  2.0   |     1      |  4   |     5     |   8   |    2860    |      1780     |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# +----------+--------------+---------+---------+----------+---------------+-----+
# | yr_built | yr_renovated | zipcode |   lat   |   long   | sqft_living15 | ... |
# +----------+--------------+---------+---------+----------+---------------+-----+
# |   1952   |      0       |  98052  | 47.6393 | -122.097 |      3140     | ... |
# +----------+--------------+---------+---------+----------+---------------+-----+
# [? rows x 23 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %% [markdown]
# ## house nr 2008000270
# It is a rather small house, with 1060 sqft living and only one floor. The price is one of the lowest of the dataset with 291850 dollar. There are 3 bedrooms and 1.5(?!) bathrooms. This house was build in 1963.

# %%
print "predict price of house nr. 2008000270"
print "         predicted: "+ str(get_house_price(houses[houses['id'] == 2008000270]['sqft_living'][0]))
print "              real: "+ str(houses[houses['id'] == 2008000270]['price'][0])
# Out:
# predict price of house nr. 2008000270
#          predicted: 251761.299134
#               real: 291850.0

# %% [markdown]
# The prediciton for the price is ~16% off.
