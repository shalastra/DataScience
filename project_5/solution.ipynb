# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn import linear_model

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,9]
pd.options.display.max_rows=8

# %%
data=pd.read_csv('../lectures/data/kc_house_data.csv', encoding = "ISO-8859-1")

# %%
data

# %%
sqft_living = data.sqft_living

# %%
sqft_living.values

# %%
price = data.price

# %%
price.values

# %%
plt.scatter(sqft_living.values, price.values)

# %% [markdown]
# # linear fit using numpy polyfit with degree 1

# %%
m, b = np.polyfit(price.values, sqft_living.values, 1)
plt.plot(price.values, sqft_living.values, 'yo', price.values, m*price.values+b, '--k')

# %% [markdown]
# # quadratic fit with numpy polyfit

# %%
c2, c1, c0 = np.polyfit(price.values, sqft_living.values, 2)
plt.plot(price.values, sqft_living.values, 'yo', price.values, c2*price.values*price.values+c1*price.values+c0, 'o')
