# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
movies=pd.read_csv('../lectures/data/movies.csv', encoding = "ISO-8859-1")
links=pd.read_csv('../lectures/data/links.csv', encoding = "ISO-8859-1")

# %%
pd.options.display.max_rows=12

# %%
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# ...        ...                                                ...
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                      Kein Bund fÃ¼r's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# 5                            Action|Crime|Thriller
# ...                                            ...
# 27272                                Comedy|Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
#
# [27278 rows x 3 columns]

# %%
links
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# 5            6   113277     949.0
# ...        ...      ...       ...
# 27272   131252   289477    9677.0
# 27273   131254   466713    4436.0
# 27274   131256   277703    9274.0
# 27275   131258  3485166  285213.0
# 27276   131260   249110   32099.0
# 27277   131262  1724965  286971.0
#
# [27278 rows x 3 columns]

# %%
merged = pd.merge(movies, links, on='movieId')

# %%
merged
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# ...        ...                                                ...
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                      Kein Bund fÃ¼r's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                             genres   imdbId    tmdbId
# 0      Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1                       Adventure|Children|Fantasy   113497    8844.0
# 2                                   Comedy|Romance   113228   15602.0
# 3                             Comedy|Drama|Romance   114885   31357.0
# 4                                           Comedy   113041   11862.0
# 5                            Action|Crime|Thriller   113277     949.0
# ...                                            ...      ...       ...
# 27272                                Comedy|Horror   289477    9677.0
# 27273                                       Comedy   466713    4436.0
# 27274                                       Comedy   277703    9274.0
# 27275                                    Adventure  3485166  285213.0
# 27276                           (no genres listed)   249110   32099.0
# 27277                     Adventure|Fantasy|Horror  1724965  286971.0
#
# [27278 rows x 5 columns]

# %%
imdb_url = 'http://www.imdb.com/title/tt'
themoviedb_url = 'https://www.themoviedb.org/movie/'

# %%
ratings = []

def get_all_ratings(url):
    for index, row in merged.iterrows():
        print(row)
        req = requests.get(url + str(row.imdbId) + '/')
        if not (req.status_code == 200):
            return False
        
        soup = BeautifulSoup(req.text, 'html5lib')
        
        rating = soup.find(itemprop='ratingValue').get_text()
        ratings.append(rating)
        
    return True

# %%
get_all_ratings(imdb_url)
# Out:
# movieId                                              1
# title                                 Toy Story (1995)
# genres     Adventure|Animation|Children|Comedy|Fantasy
# imdbId                                          114709
# tmdbId                                             862
# Name: 0, dtype: object
# movieId                             2
# title                  Jumanji (1995)
# genres     Adventure|Children|Fantasy
# imdbId                         113497
# tmdbId                           8844
# Name: 1, dtype: object
# movieId                          3
# title      Grumpier Old Men (1995)
# genres              Comedy|Romance
# imdbId                      113228
# tmdbId                       15602
# Name: 2, dtype: object
# movieId                           4
# title      Waiting to Exhale (1995)
# genres         Comedy|Drama|Romance
# imdbId                       114885
# tmdbId                        31357
# Name: 3, dtype: object
# movieId                                     5
# title      Father of the Bride Part II (1995)
# genres                                 Comedy
# imdbId                                 113041
# tmdbId                                  11862
# Name: 4, dtype: object
# movieId                        6
# title                Heat (1995)
# genres     Action|Crime|Thriller
# imdbId                    113277
# tmdbId                       949
# Name: 5, dtype: object
# movieId                 7
# title      Sabrina (1995)
# genres     Comedy|Romance
# imdbId             114319
# tmdbId              11860
# Name: 6, dtype: object
# movieId                      8
# title      Tom and Huck (1995)
# genres      Adventure|Children
# imdbId                  112302
# tmdbId                   45325
# Name: 7, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-4d2132ea2f43> in <module>()
# ----> 1 get_all_ratings(imdb_url)
#
# <ipython-input-37-824ec71648a4> in get_all_ratings(url)
#       4     for index, row in merged.iterrows():
#       5         print(row)
# ----> 6         req = requests.get(url + str(row.imdbId) + '/')
#       7         if not (req.status_code == 200):
#       8             return False
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/requests/sessions.py in <listcomp>(.0)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/datascience/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/envs/datascience/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/envs/datascience/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/envs/datascience/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/envs/datascience/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
ratings
